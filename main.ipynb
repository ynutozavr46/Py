# %%
import pandas as pd


titles = [
    "1. Number of times pregnant",
   "2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test",
   "3. Diastolic blood pressure (mm Hg)",
   "4. Triceps skin fold thickness (mm)",
   "5. 2-Hour serum insulin (mu U/ml)",
  "6. Body mass index (weight in kg/(height in m)^2)",
   "7. Diabetes pedigree function",
   "8. Age (years)",
   "9. Class variable (0 or 1)"
   ]
df = pd.read_csv('base.csv', names=titles)


df.head()
# Out:
#    1. Number of times pregnant  \
# 0                            6
# 1                            1
# 2                            8
# 3                            1
# 4                            0
#
#    2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    3. Diastolic blood pressure (mm Hg)  4. Triceps skin fold thickness (mm)  \
# 0                                   72                                   35
# 1                                   66                                   29
# 2                                   64                                    0
# 3                                   66                                   23
# 4                                   40                                   35
#
#    5. 2-Hour serum insulin (mu U/ml)  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                 94
# 4                                168
#
#    6. Body mass index (weight in kg/(height in m)^2)  \
# 0                                               33.6
# 1                                               26.6
# 2                                               23.3
# 3                                               28.1
# 4                                               43.1
#
#    7. Diabetes pedigree function  8. Age (years)  9. Class variable (0 or 1)
# 0                          0.627              50                           1
# 1                          0.351              31                           0
# 2                          0.672              32                           1
# 3                          0.167              21                           0
# 4                          2.288              33                           1

# %%
df.shape
# Out:
# (740, 9)

# %%
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# 1. Number of times pregnant                                                    0
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test    0
# 3. Diastolic blood pressure (mm Hg)                                            0
# 4. Triceps skin fold thickness (mm)                                            0
# 5. 2-Hour serum insulin (mu U/ml)                                              0
# 6. Body mass index (weight in kg/(height in m)^2)                              0
# 7. Diabetes pedigree function                                                  0
# 8. Age (years)                                                                 0
# 9. Class variable (0 or 1)                                                     0
# dtype: int64

# %%
columns = df.columns
print("Колонки датасету:", columns)
# Out:
# Колонки датасету: Index(['1. Number of times pregnant',
#        '2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        '3. Diastolic blood pressure (mm Hg)',
#        '4. Triceps skin fold thickness (mm)',
#        '5. 2-Hour serum insulin (mu U/ml)',
#        '6. Body mass index (weight in kg/(height in m)^2)',
#        '7. Diabetes pedigree function', '8. Age (years)',
#        '9. Class variable (0 or 1)'],
#       dtype='object')

# %%
mean_values = df.mean()
variance_values = df.var()
std_deviation_values = df.std()

print("\nСереднє арифметичне для кожної колонки:")
print(mean_values)

print("\nДисперсія для кожної колонки:")
print(variance_values)

print("\nСереднє квадратичне відхилення для кожної колонки:")
print(std_deviation_values)
# Out:
# Середнє арифметичне для кожної колонки:
# 1. Number of times pregnant                                                      3.764865
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test    120.556757
# 3. Diastolic blood pressure (mm Hg)                                             69.013514
# 4. Triceps skin fold thickness (mm)                                             20.671622
# 5. 2-Hour serum insulin (mu U/ml)                                               78.740541
# 6. Body mass index (weight in kg/(height in m)^2)                               32.017027
# 7. Diabetes pedigree function                                                    0.474009
# 8. Age (years)                                                                  33.001351
# 9. Class variable (0 or 1)                                                       0.341892
# dtype: float64
#
# Дисперсія для кожної колонки:
# 1. Number of times pregnant                                                       11.119197
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test     1022.820861
# 3. Diastolic blood pressure (mm Hg)                                              367.020115
# 4. Triceps skin fold thickness (mm)                                              253.165364
# 5. 2-Hour serum insulin (mu U/ml)                                              12441.948828
# 6. Body mass index (weight in kg/(height in m)^2)                                 61.634974
# 7. Diabetes pedigree function                                                      0.111139
# 8. Age (years)                                                                   136.686060
# 9. Class variable (0 or 1)                                                         0.225306
# dtype: float64
#
# Середнє квадратичне відхилення для кожної колонки:
# 1. Number of times pregnant                                                      3.334546
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test     31.981571
# 3. Diastolic blood pressure (mm Hg)                                             19.157769
# 4. Triceps skin fold thickness (mm)                                             15.911171
# 5. 2-Hour serum insulin (mu U/ml)                                              111.543484
# 6. Body mass index (weight in kg/(height in m)^2)                                7.850794
# 7. Diabetes pedigree function                                                    0.333375
# 8. Age (years)                                                                  11.691281
# 9. Class variable (0 or 1)                                                       0.474664
# dtype: float64

# %%
import matplotlib.pyplot as plt
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

df[numeric_columns].hist(bins=15, figsize=(15, 10), layout=(len(numeric_columns)//3 + 1, 3))
plt.tight_layout()
plt.show()
